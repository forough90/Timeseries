# %% [markdown]
# ### Key Question
#
#
# - What is the unit of shocks in the IRF?
#
# - Does order of variables matter in VAR?
#
# - With a sample of $n$ observations (e.g., 30 data points), is a confidence interval constructed for each data point, or for a parameter estimated from all the data?
#
# - How does the sampling distribution allow us to build a confidence interval from just one sample?
